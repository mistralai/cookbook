# %% [markdown]
# ## init
#
# Setting token to visit mistral service
#
# ```bash
# x mistral init
# ```
#
# ![image.png](attachment:image.png)
#
# Notice, you can also set default model, proxy, etc

# %%
@mistral ''


# equivalent to ...

# %%
@mistral

# starting a conversation session
